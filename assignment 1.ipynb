# %%
d1 = {}
d2 = dict

# %%
print(type(d1))
print(type(d2))
# Out:
# <class 'dict'>
# <class 'type'>

# %%
d1['name'] = 'pratap'

# %%
d1
# Out:
# {'name': 'pratap'}

# %%
l1 = ['name', 'number', 'id', 'address', 'salary']
l2 = ['aaaaa,', 11111, 10, 'hyderabad', 40000]

d3 = dict(zip(l1, l2))

# %%
d3
# Out:
# {'name': 'aaaaa,',
#  'number': 11111,
#  'id': 10,
#  'address': 'hyderabad',
#  'salary': 40000}

# %%
d4 = {'name':'bbbbbb'}

# %%
d4['name']
# Out:
# 'bbbbbb'

# %%
d5 = dict(name='pratap', number=3333)
for a in d5.items():
    print(a)
# Out:
# ('name', 'pratap')
# ('number', 3333)

# %%
def main():
    x = 10
    sub()
    
def sub():
    print('sub()')
    
main()
# Out:
# sub()

# %%
s1 = {'name', 44, 'address', 22, 89}
s2 = {'pincode', 55, 22}
s1.union(s2)
# Out:
# {22, 44, 55, 89, 'address', 'name', 'pincode'}

# %%
s1.intersection(s2)
# Out:
# {22}

# %%
import unittest

# %%
data = [3, 5, 7, 8]
result = sum(data)

try:
    assert result == 30, 'should be equal'
    print("TestCase Passed")
except AssertionError as e:
    print(e)
# Out:
# should be equal

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
r1 = os.getcwd().replace('\\','/')
r1.partition('py38')
path = 'D:/Canon Pics/Advi/advi11.jpg'

# %%
rd = plt.imread(path)
plt.imshow(rd)

# %%
name = 'pratap'
max(name)
# Out:
# 't'

# %%
ord(name[1])
number = 9849156722
n1 = [a for a in name if a not in name]
print(n1)
# chr(number[4])
# Out:
# []

# %%
s2 = 'contact'
s3 = []
for x in s2:
    if x == 't':
        break
    else:
        s3.append(x)
print("".join(s3))
# Out:
# con

# %%
s2.partition('t')[0]
# Out:
# 'con'

# %%
s4 = 'I love Python'
''. join(s4.split(' '))
# Out:
# 'IlovePython'

# %%
for s in range(1, 10):
    c = s * '* '
    print(c.center(50))
# Out:
#                         *
#                        * *
#                       * * *
#                      * * * *
#                     * * * * *
#                    * * * * * *
#                   * * * * * * *
#                  * * * * * * * *
#                 * * * * * * * * *

# %%
x = [p for p in range(1, 10)]
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
import csv
r1 = os.getcwd().replace('\\', '/') + '/nobel.csv'
with open(r1, 'r') as nbl:
    rd = csv.reader(nbl)
    next(rd)
    cnt2 = 0
    for ln in rd:
        cnt = 0
        for c in ln[3]:
            if c.isupper():
                cnt += 1
        print(" word is {0} and no of capital letters in {0} word is {1}".format(ln[3], cnt))
        cnt2 += cnt
    print(' Total capital letter are : ', cnt2)
# Out:
#  word is Physics and no of capital letters in Physics word is 1
#  word is Law and no of capital letters in Law word is 1
#  word is Physics and no of capital letters in Physics word is 1
#  word is Chemistry and no of capital letters in Chemistry word is 1
#  word is Peace and no of capital letters in Peace word is 1
#  word is Red cross and no of capital letters in Red cross word is 1
#  word is Chemistry and no of capital letters in Chemistry word is 1
#  word is Economics and no of capital letters in Economics word is 1
#  word is Physics and no of capital letters in Physics word is 1
#  word is Economics and no of capital letters in Economics word is 1
#  word is Peace and no of capital letters in Peace word is 1
#  word is Peace and no of capital letters in Peace word is 1
#  word is Literature and no of capital letters in Literature word is 1
#  word is Physics and no of capital letters in Physics word is 1
#  word is Peace and no of capital letters in Peace word is 1
# ...

# %%
for k in range(1, 10, 2):
    print((k * '*').center(30))
# Out:
#               *
#              ***
#             *****
#            *******
#           *********

# %%
m1 = list(map(lambda a1: a1 * '*', range(1, 10, 2)))
c3 = 0
def y1():
    yield m1[c3]
    c3 += 1

# %%
def sq(n):
    i = 0
    while i < n:
        yield i ** 2
        i += 1
# for j in sq(2):
#     print(j)
sq(3)
# Out:
# <generator object sq at 0x000001BF84F12E40>

# %%
def deco(func):
    def dummy():
        print("Hi this is Pratap Thigaram")
        print('my number is ', func())
        print('I am residing in Hyderabad')
    return dummy()

def func():
    return 9849156722

deco(func)
# Out:
# Hi this is Pratap Thigaram
# my number is  9849156722
# I am residing in Hyderabad

# %%
@deco
def func():
    return 9999999999
# Out:
# Hi this is Pratap Thigaram
# my number is  9999999999
# I am residing in Hyderabad

# %%
w1 = ['madam', 'rooter', 'refer', 'level', 'fgttft']
list(filter(lambda b: b != 'level',filter(lambda a: a == a[::-1], w1)))
# Out:
# ['madam', 'refer']

# %%
list(filter(lambda d: d == d[::-1], w1))
# Out:
# ['madam', 'refer', 'level']

# %%
['palindrom' if e == e[::-1] else 'Not palindrom' for e in w1]
# Out:
# ['palindrom', 'Not palindrom', 'palindrom', 'palindrom', 'Not palindrom']

# %%
import random
for f in ln:
    print(random.choice(f))
# Out:
# 9
# k
# L
# P
# m
# I

# %%
import re
text = 'Hi This is Pratap Thigaram and my age is 33 years'
fc = re.findall('Pratap Thigaram', text)
print(fc)
# Out:
# ['Pratap Thigaram']

# %%
from functools import reduce
import os
with open(os.getcwd().replace('\\','/')+'/nobel.csv', 'r') as f:
    print(list(map(lambda ln: ln , f.readlines())))
# Out:
# ['YEAR,NAME,GENDER,CATEGORY,PRIZE,MOTIVATION\n', '1903,Marie Curie,FEMALE,Physics,The Nobel Prize in Physics-1903 Awarded to Marie Curie,\n', '1904,Institute of International Law 7. 1982 - Alva Myrdal,MALE,Law,The Nobel Prize in Law-1904 Awarded to Institute of International Law 7. 1982 - Alva Myrdal,In recognition of the extraordinary services rendered and recognized in Law\n', '1905,Bertha von Suttner,FEMALE,Physics,The Nobel Prize in Physics-1905 Awarded to Bertha von Suttner,In recognition of the extraordinary services rendered and recognized in Physics\n', '1909,Selma Lagerlöf,FEMALE,Chemistry,The Nobel Prize in Chemistry-1909 Awarded to Selma Lagerlöf,In recognition of the extraordinary services rendered and recognized in Chemistry\n', '1910,Permanent International Peace Bureau 8. 1991 - Aung San Suu Kyi,MALE,Peace,The Nobel Prize in Peace-1910 Awarded to Permanent International Peace Bureau 8. 1991 - Aung San Suu Kyi,In recognition of the extraordinary services rendered and re
# ...
