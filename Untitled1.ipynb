# %%
import os
import pandas as pd
from matplotlib import pyplot

# %%
rcsv = pd.read_csv('busidx.csv')

# %%
rcsv.tail()
# Out:
#     Indx  Series reference          Period  \
# 62  K173           2019.12  PPIQ.SQUCC1300
# 63  K174           2019.09  PPIQ.SQUCC1310
# 64  K175           2019.12  PPIQ.SQUCC1310
# 65  K176           2019.12  PPIQ.SQUCC3200
# 66  K177           2019.12  PPIQ.SQUCC3210
#
#                                           Description  Revised  \
# 62  Dairy Product Manufacturing, Outputs Indexes (...     1220
# 63  Dairy Product Manufacturing, Outputs Indexes (...     1243
# 64  Dairy Product Manufacturing, Outputs Indexes (...     1220
# 65  Pulp, Paper and Converted Paper Product, Outpu...     1015
# 66  Pulp, Paper and Converted Paper Product Manufa...     1015
#
#     Initially published
# 62                 1217
# 63                 1241
# 64                 1217
# 65                 1014
# 66                 1014

# %%
rcsv.shape
# Out:
# (67, 5)

# %%
rcsv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Series reference     67 non-null     float64
#  1   Period               67 non-null     object
#  2   Description          67 non-null     object
#  3   Revised              67 non-null     int64
#  4   Initially published  67 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 2.7+ KB

# %%
pd.set_option('display.max_columns', 10)

# %%
rcsv[2:5]
# Out:
#    Series reference          Period  \
# 2           2019.09  PPIQ.SQN800001
# 3           2019.12  PPIQ.SQN800001
# 4           2019.09  PPIQ.SQN900000
#
#                                          Description  Revised  \
# 2  All industries ex admin health edu OOD, Inputs...     1167
# 3  All industries ex admin health edu OOD, Inputs...     1170
# 4           All industries, Inputs Indexes (Level 0)     1166
#
#    Initially published
# 2                 1164
# 3                 1166
# 4                 1164

# %%
rcsv
# Out:
#     Series reference          Period  \
# 0            2019.09  PPIQ.SQN800000
# 1            2019.12  PPIQ.SQN800000
# 2            2019.09  PPIQ.SQN800001
# 3            2019.12  PPIQ.SQN800001
# 4            2019.09  PPIQ.SQN900000
# ..               ...             ...
# 62           2019.12  PPIQ.SQUCC1300
# 63           2019.09  PPIQ.SQUCC1310
# 64           2019.12  PPIQ.SQUCC1310
# 65           2019.12  PPIQ.SQUCC3200
# 66           2019.12  PPIQ.SQUCC3210
#
#                                           Description  Revised  \
# 0   All industries excl admin health educati, Inpu...     1167
# 1   All industries excl admin health educati, Inpu...     1170
# 2   All industries ex admin health edu OOD, Inputs...     1167
# 3   All industries ex admin health edu OOD, Inputs...     1170
# 4            All industries, Inputs Indexes (Level 0)     1166
# ..                                                ...      ...
# 62  Dairy Product Manufacturing, Outputs Indexes (...     1220
# ...

# %%
rcsv.iloc[[62, 63], 1]
# Out:
# 62    PPIQ.SQUCC1300
# 63    PPIQ.SQUCC1310
# Name: Period, dtype: object

# %%
rcsv.loc[[34, 38], 'Period']
# Out:
# 34    PPIQ.SQUAA1000
# 38    PPIQ.SQUAA1110
# Name: Period, dtype: object

# %%
rcsv.columns
# Out:
# Index(['Series reference', 'Period', 'Description', 'Revised',
#        'Initially published'],
#       dtype='object')

# %%
rcsv.index
# Out:
# RangeIndex(start=0, stop=67, step=1)

# %%
rcsv
# Out:
#                                                     Series reference  \
# Description
# All industries excl admin health educati, Input...           2019.09
# All industries excl admin health educati, Input...           2019.12
# All industries ex admin health edu OOD, Inputs ...           2019.09
# All industries ex admin health edu OOD, Inputs ...           2019.12
# All industries, Inputs Indexes (Level 0)                     2019.09
# ...                                                              ...
# Dairy Product Manufacturing, Outputs Indexes (L...           2019.12
# Dairy Product Manufacturing, Outputs Indexes (L...           2019.09
# Dairy Product Manufacturing, Outputs Indexes (L...           2019.12
# Pulp, Paper and Converted Paper Product, Output...           2019.12
# Pulp, Paper and Converted Paper Product Manufac...           2019.12
#
#                                                             Period  Revised  \
# Description
# ...

# %%
rcsv.set_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-0d714587bb19> in <module>
# ----> 1 rcsv.set_index(inplace=True)
#
# TypeError: set_index() missing 1 required positional argument: 'keys'

# %%
rcsv
# Out:
#                                                     Series reference  \
# Description
# All industries excl admin health educati, Input...           2019.09
# All industries excl admin health educati, Input...           2019.12
# All industries ex admin health edu OOD, Inputs ...           2019.09
# All industries ex admin health edu OOD, Inputs ...           2019.12
# All industries, Inputs Indexes (Level 0)                     2019.09
# ...                                                              ...
# Dairy Product Manufacturing, Outputs Indexes (L...           2019.12
# Dairy Product Manufacturing, Outputs Indexes (L...           2019.09
# Dairy Product Manufacturing, Outputs Indexes (L...           2019.12
# Pulp, Paper and Converted Paper Product, Output...           2019.12
# Pulp, Paper and Converted Paper Product Manufac...           2019.12
#
#                                                             Period  Revised  \
# Description
# ...

# %%
rcsv.reset_index(inplace=True)

# %%
rcsv.set_index('Indx', inplace=True)

# %%
rcsv
# Out:
#       Series reference          Period  \
# Indx
# K111           2019.09  PPIQ.SQN800000
# K112           2019.12  PPIQ.SQN800000
# K113           2019.09  PPIQ.SQN800001
# K114           2019.12  PPIQ.SQN800001
# K115           2019.09  PPIQ.SQN900000
# ...                ...             ...
# K173           2019.12  PPIQ.SQUCC1300
# K174           2019.09  PPIQ.SQUCC1310
# K175           2019.12  PPIQ.SQUCC1310
# K176           2019.12  PPIQ.SQUCC3200
# K177           2019.12  PPIQ.SQUCC3210
#
#                                             Description  Revised  \
# Indx
# K111  All industries excl admin health educati, Inpu...     1167
# K112  All industries excl admin health educati, Inpu...     1170
# K113  All industries ex admin health edu OOD, Inputs...     1167
# K114  All industries ex admin health edu OOD, Inputs...     1170
# K115           All industries, Inputs Indexes (Level 0)     1166
# ...                                                 ...      ...
# ...

# %%
rcsv.loc['K113', 'Description']
# Out:
# 'All industries ex admin health edu OOD, Inputs Indexes (Level 0)'

# %%
rcsv.loc['K177']
# Out:
# Series reference                                                 2019.12
# Period                                                    PPIQ.SQUCC3210
# Description            Pulp, Paper and Converted Paper Product Manufa...
# Revised                                                             1015
# Initially published                                                 1014
# Name: K177, dtype: object

# %%
pd.set_option('display.max_columns', 10)
rcsv
# Out:
#       Series reference          Period  \
# Indx
# K111           2019.09  PPIQ.SQN800000
# K112           2019.12  PPIQ.SQN800000
# K113           2019.09  PPIQ.SQN800001
# K114           2019.12  PPIQ.SQN800001
# K115           2019.09  PPIQ.SQN900000
# ...                ...             ...
# K173           2019.12  PPIQ.SQUCC1300
# K174           2019.09  PPIQ.SQUCC1310
# K175           2019.12  PPIQ.SQUCC1310
# K176           2019.12  PPIQ.SQUCC3200
# K177           2019.12  PPIQ.SQUCC3210
#
#                                             Description  Revised  \
# Indx
# K111  All industries excl admin health educati, Inpu...     1167
# K112  All industries excl admin health educati, Inpu...     1170
# K113  All industries ex admin health edu OOD, Inputs...     1167
# K114  All industries ex admin health edu OOD, Inputs...     1170
# K115           All industries, Inputs Indexes (Level 0)     1166
# ...                                                 ...      ...
# ...

# %%
dff = pd.DataFrame(rcsv)

# %%
dff.columns
# Out:
# Index(['Series reference', 'Period', 'Description', 'Revised',
#        'Initially published'],
#       dtype='object')

# %%
flt1 = rcsv['Revised'] == 1220

# %%
rcsv[flt1].iloc[0:2, 2:3]
# Out:
#                                             Description
# Indx
# K173  Dairy Product Manufacturing, Outputs Indexes (...
# K175  Dairy Product Manufacturing, Outputs Indexes (...
